# %% [markdown]
# # MLP Demo

# %% [markdown]
# ## Import Statements

# %%
import MLP
import numpy as np

# %% [markdown]
# ## Binary

# %%
# Load data
dataset = np.load('data/fulldata.npy')

# %%
nodes_list = [[[676, 338],[338, 169],[224, 112],[128, 64],[64, 32]],
              [[676, 338, 169, 84],[338, 169, 84, 42],[169, 84, 42, 24],[84, 42, 24, 12],[42, 24, 12, 6]],
              [[1352, 676, 338, 169, 84, 42],[676, 338, 169, 84, 42, 24],[338, 169, 84, 42, 24, 12],[169, 84, 42, 24, 12, 6],[84, 42, 24, 12, 6, 3]]]

# %%
n_epochs = 30
for i in range(3):
    for nodes in nodes_list[i]:
        print('Nodes: {}'.format(nodes))
        MLP.binary(dataset, n_epochs, nodes, batch_size = 128, upper_y_lim = 1, p = 0.5)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Nodes: [676, 338]
# 100%|██████████| 30/30 [00:04<00:00,  6.88it/s]
#               precision    recall  f1-score   support
#
#            0     0.7101    0.8015    0.7530       272
#            1     0.4706    0.3504    0.4017       137
#
#     accuracy                         0.6504       409
#    macro avg     0.5903    0.5759    0.5773       409
# weighted avg     0.6299    0.6504    0.6353       409
#
#
# TN: 218 FP: 54 FN: 89 TP: 48
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.639
# MLP: f1=0.402 auc=0.486
# Nodes: [338, 169]
# 100%|██████████| 30/30 [00:04<00:00,  7.04it/s]
#               precision    recall  f1-score   support
#
#            0     0.7347    0.7660    0.7500       282
#            1     0.4261    0.3858    0.4050       127
#
#     accuracy                         0.6479       409
#    macro avg     0.5804    0.5759    0.5775       409
# weighted avg     0.6389    0.6479    0.6429       409
#
#
# TN: 216 FP: 66 FN: 78 TP: 49
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.628
# MLP: f1=0.405 auc=0.428
# Nodes: [224, 112]
# 100%|██████████| 30/30 [00:04<00:00,  7.00it/s]
#               precision    recall  f1-score   support
#
#            0     0.7680    0.6486    0.7033       296
#            1     0.3459    0.4867    0.4044       113
#
#     accuracy                         0.6039       409
#    macro avg     0.5570    0.5677    0.5539       409
# weighted avg     0.6514    0.6039    0.6207       409
#
#
# TN: 192 FP: 104 FN: 58 TP: 55
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.607
# MLP: f1=0.404 auc=0.346
# Nodes: [128, 64]
# 100%|██████████| 30/30 [00:04<00:00,  6.32it/s]
#               precision    recall  f1-score   support
#
#            0     0.7686    0.6782    0.7206       289
#            1     0.3961    0.5083    0.4453       120
#
#     accuracy                         0.6284       409
#    macro avg     0.5824    0.5933    0.5829       409
# weighted avg     0.6593    0.6284    0.6398       409
#
#
# TN: 196 FP: 93 FN: 59 TP: 61
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.655
# MLP: f1=0.445 auc=0.407
# Nodes: [64, 32]
# 100%|██████████| 30/30 [00:04<00:00,  7.09it/s]
#               precision    recall  f1-score   support
#
#            0     0.8125    0.6212    0.7041       293
#            1     0.4000    0.6379    0.4917       116
#
#     accuracy                         0.6259       409
#    macro avg     0.6062    0.6295    0.5979       409
# weighted avg     0.6955    0.6259    0.6438       409
#
#
# TN: 182 FP: 111 FN: 42 TP: 74
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.661
# MLP: f1=0.492 auc=0.454
# Nodes: [676, 338, 169, 84]
# 100%|██████████| 30/30 [00:06<00:00,  4.88it/s]
#               precision    recall  f1-score   support
#
#            0     0.7520    0.6787    0.7135       277
#            1     0.4403    0.5303    0.4811       132
#
#     accuracy                         0.6308       409
#    macro avg     0.5961    0.6045    0.5973       409
# weighted avg     0.6514    0.6308    0.6385       409
#
#
# TN: 188 FP: 89 FN: 62 TP: 70
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.629
# MLP: f1=0.481 auc=0.427
# Nodes: [338, 169, 84, 42]
# 100%|██████████| 30/30 [00:06<00:00,  4.88it/s]
#               precision    recall  f1-score   support
#
#            0     0.7774    0.7483    0.7626       294
#            1     0.4127    0.4522    0.4315       115
#
#     accuracy                         0.6650       409
#    macro avg     0.5950    0.6002    0.5971       409
# weighted avg     0.6748    0.6650    0.6695       409
#
#
# TN: 220 FP: 74 FN: 63 TP: 52
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.619
# MLP: f1=0.432 auc=0.430
# Nodes: [169, 84, 42, 24]
# 100%|██████████| 30/30 [00:06<00:00,  4.94it/s]
#               precision    recall  f1-score   support
#
#            0     0.7626    0.6806    0.7193       288
#            1     0.3947    0.4959    0.4396       121
#
#     accuracy                         0.6259       409
#    macro avg     0.5787    0.5882    0.5794       409
# weighted avg     0.6538    0.6259    0.6365       409
#
#
# TN: 196 FP: 92 FN: 61 TP: 60
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.620
# MLP: f1=0.440 auc=0.386
# Nodes: [84, 42, 24, 12]
# 100%|██████████| 30/30 [00:06<00:00,  4.91it/s]
#               precision    recall  f1-score   support
#
#            0     0.7432    0.7331    0.7381       296
#            1     0.3248    0.3363    0.3304       113
#
#     accuracy                         0.6235       409
#    macro avg     0.5340    0.5347    0.5343       409
# weighted avg     0.6276    0.6235    0.6255       409
#
#
# TN: 217 FP: 79 FN: 75 TP: 38
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.549
# MLP: f1=0.330 auc=0.320
# Nodes: [42, 24, 12, 6]
# 100%|██████████| 30/30 [00:06<00:00,  4.96it/s]
#               precision    recall  f1-score   support
#
#            0     0.7716    0.6416    0.7006       279
#            1     0.4350    0.5923    0.5016       130
#
#     accuracy                         0.6259       409
#    macro avg     0.6033    0.6169    0.6011       409
# weighted avg     0.6646    0.6259    0.6373       409
#
#
# TN: 179 FP: 100 FN: 53 TP: 77
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.651
# MLP: f1=0.502 auc=0.453
# Nodes: [1352, 676, 338, 169, 84, 42]
# 100%|██████████| 30/30 [00:08<00:00,  3.74it/s]
#               precision    recall  f1-score   support
#
#            0     0.7860    0.6609    0.7180       289
#            1     0.4096    0.5667    0.4755       120
#
#     accuracy                         0.6333       409
#    macro avg     0.5978    0.6138    0.5968       409
# weighted avg     0.6756    0.6333    0.6469       409
#
#
# TN: 191 FP: 98 FN: 52 TP: 68
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.647
# MLP: f1=0.476 auc=0.408
# Nodes: [676, 338, 169, 84, 42, 24]
# 100%|██████████| 30/30 [00:08<00:00,  3.63it/s]
#               precision    recall  f1-score   support
#
#            0     0.8044    0.6220    0.7016       291
#            1     0.4022    0.6271    0.4901       118
#
#     accuracy                         0.6235       409
#    macro avg     0.6033    0.6246    0.5958       409
# weighted avg     0.6884    0.6235    0.6405       409
#
#
# TN: 181 FP: 110 FN: 44 TP: 74
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.622
# MLP: f1=0.490 auc=0.357
# Nodes: [338, 169, 84, 42, 24, 12]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
#               precision    recall  f1-score   support
#
#            0     0.7821    0.6931    0.7349       290
#            1     0.4145    0.5294    0.4649       119
#
#     accuracy                         0.6455       409
#    macro avg     0.5983    0.6113    0.5999       409
# weighted avg     0.6751    0.6455    0.6564       409
#
#
# TN: 201 FP: 89 FN: 56 TP: 63
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.658
# MLP: f1=0.465 auc=0.438
# Nodes: [169, 84, 42, 24, 12, 6]
# 100%|██████████| 30/30 [00:08<00:00,  3.72it/s]
#               precision    recall  f1-score   support
#
#            0     0.7456    0.6159    0.6746       276
#            1     0.4144    0.5639    0.4777       133
#
#     accuracy                         0.5990       409
#    macro avg     0.5800    0.5899    0.5762       409
# weighted avg     0.6379    0.5990    0.6106       409
#
#
# TN: 170 FP: 106 FN: 58 TP: 75
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.630
# MLP: f1=0.478 auc=0.439
# Nodes: [84, 42, 24, 12, 6, 3]
# 100%|██████████| 30/30 [00:08<00:00,  3.75it/s]
#               precision    recall  f1-score   support
#
#            0     0.7826    0.6972    0.7374       284
#            1     0.4487    0.5600    0.4982       125
#
#     accuracy                         0.6553       409
#    macro avg     0.6157    0.6286    0.6178       409
# weighted avg     0.6806    0.6553    0.6643       409
#
#
# TN: 198 FP: 86 FN: 55 TP: 70
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.684
# MLP: f1=0.498 auc=0.491

# %% [markdown]
# ### Multilabel

# %%
# Load data
dataset = np.load('data/fulldata.npy')

# %%
num_y = 14
n_epochs = 10
nodes = [128, 64]
model = MLP.multilabel(dataset, num_y, n_epochs, nodes, batch_size = 32, upper_y_lim = 1, p = 0.5)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.04it/s]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0     0.8080    1.0000    0.8938       547
#            1     0.0000    0.0000    0.0000       130
#
#     accuracy                         0.8080       677
#    macro avg     0.4040    0.5000    0.4469       677
# weighted avg     0.6528    0.8080    0.7222       677
#
#
# TN: 547 FP: 0 FN: 130 TP: 0
#
# No Skill: ROC AUC=0.500
# MLP: ROC AUC=0.644
# MLP: f1=0.000 auc=0.275
